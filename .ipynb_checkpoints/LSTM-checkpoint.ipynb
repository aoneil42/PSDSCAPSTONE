# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
pd.set_option('display.float_format', lambda x: '%.4f' % x)
import seaborn as sns
sns.set_context("paper", font_scale=1.3)
sns.set_style('white')
import warnings
warnings.filterwarnings('ignore')
from time import time
import matplotlib.ticker as tkr
from scipy import stats
from statsmodels.tsa.stattools import adfuller
from sklearn import preprocessing
from statsmodels.tsa.stattools import pacf
# %matplotlib inline

import math
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.callbacks import EarlyStopping
from keras.layers import Bidirectional
# Out:
# Using TensorFlow backend.

# %%
casediff = pd.read_csv("casediff.csv", index_col=0)
deathdiff = pd.read_csv("deathdiff.csv", index_col=0)

# %%
casediff.columns
# Out:
# Index(['Argentina', 'Belgium', 'Chile', 'China (People's Republic of)',
#        'Colombia', 'India', 'Israel', 'Japan', 'Korea', 'Luxembourg', 'Spain',
#        'United Kingdom', 'United States'],
#       dtype='object')

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

def lstmseq(raw_seq,n_steps=7):
    X, y = split_sequence(raw_seq, n_steps)
    n_features = 1
    X = X.reshape((X.shape[0], X.shape[1], n_features))
    model = Sequential()
    model.add(LSTM(50, activation='relu', input_shape=(n_steps, n_features)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    model.fit(X, y, epochs=200, verbose=0)
    
def lstmbi(raw_seq,n_steps=7):
    X, y = split_sequence(raw_seq, n_steps)
    n_features = 1
    X = X.reshape((X.shape[0], X.shape[1], n_features))
    model = Sequential()
    model.add(Bidirectional(LSTM(50, activation='relu', input_shape=(n_steps, n_features))))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    model.fit(X, y, epochs=200, verbose=0)
    
def normtest(raw_seq):
    stat, p = stats.normaltest(raw_seq)
    print('Statistics=%.3f, p=%.3f' % (stat, p))
    alpha = 0.05
    if p > alpha:
        print('Data looks Gaussian (fail to reject H0)')
    else:
        print('Data does not look Gaussian (reject H0)')
    sns.distplot(raw_seq);
    print( 'Kurtosis of normal distribution: {}'.format(stats.kurtosis(raw_seq)))
    print( 'Skewness of normal distribution: {}'.format(stats.skew(raw_seq)))
    df1=raw_seq
    df1.plot(figsize=(12,5))
    plt.ylabel('Rate of change per 100k')
    plt.legend().set_visible(False)
    plt.tight_layout()
    plt.title('Covid Time Series')
    sns.despine(top=True)
    plt.show();
    
def lstmseq2(raw_seq,look_back=14):
    dataset = raw_seq.values
    dataset = dataset.astype('float32')
    dataset = np.reshape(dataset, (-1, 1))
    scaler = MinMaxScaler(feature_range=(0, 1))
    dataset = scaler.fit_transform(dataset)
    train_size = int(len(dataset) * 0.80)
    test_size = len(dataset) - train_size
    train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
    X_train, Y_train = create_dataset(train, look_back)
    X_test, Y_test = create_dataset(test, look_back)
    X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
    X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
    model = Sequential()
    model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    history = model.fit(X_train, Y_train, epochs=100, batch_size=70, validation_data=(X_test, Y_test), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=10)], verbose=0, shuffle=False)
    model.summary()
    train_predict = model.predict(X_train)
    test_predict = model.predict(X_test)
    train_predict = scaler.inverse_transform(train_predict)
    Y_train = scaler.inverse_transform([Y_train])
    test_predict = scaler.inverse_transform(test_predict)
    Y_test = scaler.inverse_transform([Y_test])
    print('Train Mean Absolute Error:', mean_absolute_error(Y_train[0], train_predict[:,0]))
    print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_train[0], train_predict[:,0])))
    print('Test Mean Absolute Error:', mean_absolute_error(Y_test[0], test_predict[:,0]))
    print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test[0], test_predict[:,0])))
    return history, test_predict, Y_test

def lstmbi2(raw_seq,look_back=14):
    dataset = raw_seq.values
    dataset = dataset.astype('float32')
    dataset = np.reshape(dataset, (-1, 1))
    scaler = MinMaxScaler(feature_range=(0, 1))
    dataset = scaler.fit_transform(dataset)
    train_size = int(len(dataset) * 0.80)
    test_size = len(dataset) - train_size
    train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
    X_train, Y_train = create_dataset(train, look_back)
    X_test, Y_test = create_dataset(test, look_back)
    X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
    X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
    model = Sequential()
    model.add(Bidirectional(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2]))))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    history = model.fit(X_train, Y_train, epochs=100, batch_size=70, validation_data=(X_test, Y_test), 
                    callbacks=[EarlyStopping(monitor='val_loss', patience=10)], verbose=0, shuffle=False)
    model.summary()
    train_predict = model.predict(X_train)
    test_predict = model.predict(X_test)
    train_predict = scaler.inverse_transform(train_predict)
    Y_train = scaler.inverse_transform([Y_train])
    test_predict = scaler.inverse_transform(test_predict)
    Y_test = scaler.inverse_transform([Y_test])
    print('Train Mean Absolute Error:', mean_absolute_error(Y_train[0], train_predict[:,0]))
    print('Train Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_train[0], train_predict[:,0])))
    print('Test Mean Absolute Error:', mean_absolute_error(Y_test[0], test_predict[:,0]))
    print('Test Root Mean Squared Error:',np.sqrt(mean_squared_error(Y_test[0], test_predict[:,0])))
    return history, test_predict, Y_test

# %%
for col in casediff.columns:
    print(col)
    raw_seq = casediff[col]
    normtest(raw_seq)
    history, test_predict, Y_test = lstmseq2(raw_seq)
    plt.figure(figsize=(8,4))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Test Loss')
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epochs')
    plt.legend(loc='upper right')
    plt.show();
    aa=[x for x in range(len(test_predict))]
    plt.figure(figsize=(8,4))
    plt.plot(aa, Y_test[0], marker='.', label="actual")
    plt.plot(aa, test_predict[:,0], 'r', label="prediction")
    plt.tight_layout()
    sns.despine(top=True)
    plt.subplots_adjust(left=0.07)
    plt.ylabel('Rate of Change per 100k', size=15)
    plt.xlabel('Time step', size=15)
    plt.legend(fontsize=15)
    plt.show();
    history, test_predict, Y_test = lstmbi2(raw_seq)
    plt.figure(figsize=(8,4))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Test Loss')
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epochs')
    plt.legend(loc='upper right')
    plt.show();
    aa=[x for x in range(len(test_predict))]
    plt.figure(figsize=(8,4))
    plt.plot(aa, Y_test[0], marker='.', label="actual")
    plt.plot(aa, test_predict[:,0], 'r', label="prediction")
    plt.tight_layout()
    sns.despine(top=True)
    plt.subplots_adjust(left=0.07)
    plt.ylabel('Rate of Change per 100k', size=15)
    plt.xlabel('Time step', size=15)
    plt.legend(fontsize=15)
    plt.show();
# Out:
# Argentina
# Statistics=156.982, p=0.000
# Data does not look Gaussian (reject H0)
# Kurtosis of normal distribution: -1.1724147837318015
# Skewness of normal distribution: 0.5852004447503214
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100)               46000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 46,101
# Trainable params: 46,101
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 1.2097298886544914
# Train Root Mean Squared Error: 1.3939923864900707
# Test Mean Absolute Error: 2.9299246971432114
# Test Root Mean Squared Error: 3.2780615685958154
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_1 (Bidirection (None, 200)               92000
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 201
# =================================================================
# Total params: 92,201
# Trainable params: 92,201
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 1.2905369980858328
# Train Root Mean Squared Error: 1.5171438957010708
# Test Mean Absolute Error: 2.724011769267887
# Test Root Mean Squared Error: 3.0219126309734965
# Belgium
# Statistics=199.373, p=0.000
# Data does not look Gaussian (reject H0)
# Kurtosis of normal distribution: 7.753202373569588
# Skewness of normal distribution: 2.8517108270378753
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 100)               46000
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 46,101
# Trainable params: 46,101
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.490322988065004
# Train Root Mean Squared Error: 0.6558010817634251
# Test Mean Absolute Error: 13.12832062374221
# Test Root Mean Squared Error: 15.337471880242212
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_2 (Bidirection (None, 200)               92000
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 201
# =================================================================
# Total params: 92,201
# Trainable params: 92,201
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.46633657562711184
# Train Root Mean Squared Error: 0.612166258758737
# Test Mean Absolute Error: 11.208393513678939
# Test Root Mean Squared Error: 13.159509577126082
# Chile
# Statistics=58.166, p=0.000
# Data does not look Gaussian (reject H0)
# Kurtosis of normal distribution: 0.9283982704478024
# Skewness of normal distribution: 1.2110493538510174
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 100)               46000
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 46,101
# Trainable params: 46,101
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 2.2097427798284923
# Train Root Mean Squared Error: 3.10856287007853
# Test Mean Absolute Error: 0.773670216621029
# Test Root Mean Squared Error: 0.7957945728636482
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_3 (Bidirection (None, 200)               92000
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 201
# =================================================================
# Total params: 92,201
# Trainable params: 92,201
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 1.7146390052053582
# Train Root Mean Squared Error: 2.537602712111902
# Test Mean Absolute Error: 0.4915712942973556
# Test Root Mean Squared Error: 0.526090936642383
# China (People's Republic of)
# Statistics=261.841, p=0.000
# Data does not look Gaussian (reject H0)
# Kurtosis of normal distribution: 13.295807871183769
# Skewness of normal distribution: 3.7562903489553863
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 100)               46000
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 46,101
# Trainable params: 46,101
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.003433435816991946
# Train Root Mean Squared Error: 0.01144873464180728
# Test Mean Absolute Error: 0.0009811635132065597
# Test Root Mean Squared Error: 0.0010175967134539643
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_4 (Bidirection (None, 200)               92000
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 201
# =================================================================
# Total params: 92,201
# Trainable params: 92,201
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.0026767769759679593
# Train Root Mean Squared Error: 0.008406247936875279
# Test Mean Absolute Error: 0.0005266524855967383
# Test Root Mean Squared Error: 0.0006584198854927021
# Colombia
# Statistics=2629.687, p=0.000
# Data does not look Gaussian (reject H0)
# Kurtosis of normal distribution: -1.567434389517103
# Skewness of normal distribution: 0.2183170665163361
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_9 (LSTM)                (None, 100)               46000
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 46,101
# Trainable params: 46,101
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.6018171367517071
# Train Root Mean Squared Error: 0.8597117828568511
# Test Mean Absolute Error: 1.0946344681350362
# Test Root Mean Squared Error: 1.253327815556367
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_5 (Bidirection (None, 200)               92000
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 201
# =================================================================
# Total params: 92,201
# Trainable params: 92,201
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.44785848862400274
# Train Root Mean Squared Error: 0.6202552595578489
# Test Mean Absolute Error: 1.0242764244338514
# Test Root Mean Squared Error: 1.161239212310052
# India
# Statistics=125.863, p=0.000
# Data does not look Gaussian (reject H0)
# Kurtosis of normal distribution: -1.132574538500222
# Skewness of normal distribution: 0.5363567597015141
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_11 (LSTM)               (None, 100)               46000
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 46,101
# Trainable params: 46,101
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.37476397621429014
# Train Root Mean Squared Error: 0.40995922117895306
# Test Mean Absolute Error: 0.46370264425180013
# Test Root Mean Squared Error: 0.5467293774551734
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_6 (Bidirection (None, 200)               92000
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 201
# =================================================================
# Total params: 92,201
# Trainable params: 92,201
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.3307354074002728
# Train Root Mean Squared Error: 0.3744972447926875
# Test Mean Absolute Error: 0.4169947055806226
# Test Root Mean Squared Error: 0.5004551882926168
# Israel
# Statistics=123.519, p=0.000
# Data does not look Gaussian (reject H0)
# Kurtosis of normal distribution: 3.2932767707483723
# Skewness of normal distribution: 1.94175513096512
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_13 (LSTM)               (None, 100)               46000
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 46,101
# Trainable params: 46,101
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 4.855018584746305
# Train Root Mean Squared Error: 5.3479669231619935
# Test Mean Absolute Error: 12.46408276170823
# Test Root Mean Squared Error: 16.4056124691088
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_7 (Bidirection (None, 200)               92000
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 201
# =================================================================
# Total params: 92,201
# Trainable params: 92,201
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 4.481638695107109
# Train Root Mean Squared Error: 4.948490229838815
# Test Mean Absolute Error: 11.053680341988938
# Test Root Mean Squared Error: 14.369814940741373
# Japan
# Statistics=83.618, p=0.000
# Data does not look Gaussian (reject H0)
# Kurtosis of normal distribution: 1.9089096338460259
# Skewness of normal distribution: 1.4707307605533375
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_15 (LSTM)               (None, 100)               46000
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 46,101
# Trainable params: 46,101
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.07427137299738017
# Train Root Mean Squared Error: 0.09955626913774819
# Test Mean Absolute Error: 0.2219267466691206
# Test Root Mean Squared Error: 0.2784259019956162
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_8 (Bidirection (None, 200)               92000
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 201
# =================================================================
# Total params: 92,201
# Trainable params: 92,201
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.07205417988680128
# Train Root Mean Squared Error: 0.09243456878967955
# Test Mean Absolute Error: 0.17332908556451246
# Test Root Mean Squared Error: 0.22496230956054983
# Korea
# Statistics=129.878, p=0.000
# Data does not look Gaussian (reject H0)
# Kurtosis of normal distribution: 3.727471638631437
# Skewness of normal distribution: 1.9936386173065301
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_17 (LSTM)               (None, 100)               46000
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 46,101
# Trainable params: 46,101
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.025446919196290795
# Train Root Mean Squared Error: 0.04160089002914583
# Test Mean Absolute Error: 0.039197800831772586
# Test Root Mean Squared Error: 0.05983713056970755
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_9 (Bidirection (None, 200)               92000
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 201
# =================================================================
# Total params: 92,201
# Trainable params: 92,201
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.02210897507089696
# Train Root Mean Squared Error: 0.034373476357559794
# Test Mean Absolute Error: 0.02997690035036826
# Test Root Mean Squared Error: 0.044391568459170576
# Luxembourg
# Statistics=112.458, p=0.000
# Data does not look Gaussian (reject H0)
# Kurtosis of normal distribution: 2.426207613235274
# Skewness of normal distribution: 1.8793088834230467
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_19 (LSTM)               (None, 100)               46000
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 46,101
# Trainable params: 46,101
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 4.268636348609289
# Train Root Mean Squared Error: 6.923416805217339
# Test Mean Absolute Error: 25.38882356526585
# Test Root Mean Squared Error: 29.674270477370946
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_10 (Bidirectio (None, 200)               92000
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 201
# =================================================================
# Total params: 92,201
# Trainable params: 92,201
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 4.453129040176378
# Train Root Mean Squared Error: 6.778876612731979
# Test Mean Absolute Error: 22.951381536489723
# Test Root Mean Squared Error: 27.419713195791385
# Spain
# Statistics=41.837, p=0.000
# Data does not look Gaussian (reject H0)
# Kurtosis of normal distribution: 0.13317021714231103
# Skewness of normal distribution: 1.046123279083854
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_21 (LSTM)               (None, 100)               46000
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 46,101
# Trainable params: 46,101
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.8427199342733747
# Train Root Mean Squared Error: 1.2439353396384563
# Test Mean Absolute Error: 2.4116779927597167
# Test Root Mean Squared Error: 2.918033852785951
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_11 (Bidirectio (None, 200)               92000
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 201
# =================================================================
# Total params: 92,201
# Trainable params: 92,201
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.7820161272894025
# Train Root Mean Squared Error: 1.1308339159734835
# Test Mean Absolute Error: 1.7889406572893782
# Test Root Mean Squared Error: 2.3700927676163492
# United Kingdom
# Statistics=80.160, p=0.000
# Data does not look Gaussian (reject H0)
# Kurtosis of normal distribution: 0.9694888277464737
# Skewness of normal distribution: 1.5718512873481072
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_23 (LSTM)               (None, 100)               46000
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 46,101
# Trainable params: 46,101
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.7195197739741591
# Train Root Mean Squared Error: 0.8711855119084075
# Test Mean Absolute Error: 5.499969143554268
# Test Root Mean Squared Error: 7.037701457215266
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_12 (Bidirectio (None, 200)               92000
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 201
# =================================================================
# Total params: 92,201
# Trainable params: 92,201
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 0.6349374180776485
# Train Root Mean Squared Error: 0.8049057667691587
# Test Mean Absolute Error: 4.5569687537453305
# Test Root Mean Squared Error: 5.920729920005132
# United States
# Statistics=103.102, p=0.000
# Data does not look Gaussian (reject H0)
# Kurtosis of normal distribution: 2.7678508181959645
# Skewness of normal distribution: 1.6651050569321
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_25 (LSTM)               (None, 100)               46000
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 46,101
# Trainable params: 46,101
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 1.5456682702656301
# Train Root Mean Squared Error: 1.7809381667470063
# Test Mean Absolute Error: 8.243908251354991
# Test Root Mean Squared Error: 9.265917569605312
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_13 (Bidirectio (None, 200)               92000
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 201
# =================================================================
# Total params: 92,201
# Trainable params: 92,201
# Non-trainable params: 0
# _________________________________________________________________
# Train Mean Absolute Error: 1.6257795335513194
# Train Root Mean Squared Error: 1.7870881339791065
# Test Mean Absolute Error: 7.168496089548195
# Test Root Mean Squared Error: 8.235170791630585
